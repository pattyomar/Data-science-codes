# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
# %matplotlib inline

# %%
retail_df = pd.read_csv(r"E:\My Python codes\QVI_transaction_data.csv")
retail_df
# Out:
#               DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       10/17/2018          1            1000       1         5
# 1        5/14/2019          1            1307     348        66
# 2        5/20/2019          1            1343     383        61
# 3        8/17/2018          2            2373     974        69
# 4        8/18/2018          2            2426    1038       108
# ...            ...        ...             ...     ...       ...
# 264831    3/9/2019        272          272319  270088        89
# 264832   8/13/2018        272          272358  270154        74
# 264833   11/6/2018        272          272379  270187        51
# 264834  12/27/2018        272          272379  270188        42
# 264835   9/22/2018        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# 2         Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3         Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4       Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
# ...                                          ...       ...        ...
# 264831   Kettle Sweet Chilli And Sour Cream 175g         2       10.8
# 264832             Tostitos Splash Of  Lime 175g         1        4.4
# 264833                  Doritos Mexicana    170g         2        8.8
# 264834   Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 264835             Tostitos Splash Of  Lime 175g         2        8.8
#
# [264836 rows x 8 columns]

# %%
retail_df.info()
#No Null values but the date column is in string format
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  object
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 16.2+ MB

# %%
retail_df.drop_duplicates(keep=False,inplace=True)

# %%
#Convert Date column to datetime format
retail_df.loc[:,'DATE'] = pd.to_datetime(retail_df.loc[:,'DATE'], format= '%m/%d/%Y')

retail_df
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0      2018-10-17          1            1000       1         5
# 1      2019-05-14          1            1307     348        66
# 2      2019-05-20          1            1343     383        61
# 3      2018-08-17          2            2373     974        69
# 4      2018-08-18          2            2426    1038       108
# ...           ...        ...             ...     ...       ...
# 264831 2019-03-09        272          272319  270088        89
# 264832 2018-08-13        272          272358  270154        74
# 264833 2018-11-06        272          272379  270187        51
# 264834 2018-12-27        272          272379  270188        42
# 264835 2018-09-22        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# 2         Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3         Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4       Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
# ...                                          ...       ...        ...
# 264831   Kettle Sweet Chilli And Sour Cream 175g         2       10.8
# 264832             Tostitos Splash Of  Lime 175g         1        4.4
# 264833                  Doritos Mexicana    170g         2        8.8
# 264834   Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 264835             Tostitos Splash Of  Lime 175g         2        8.8
#
# [264834 rows x 8 columns]

# %%
#Let's check if there's anything other than chips
retail_df['PROD_NAME'].unique()
#Looks like the list also includes salsa sauces. From the Summary below we can see that salsa dips are 300g in weight. 
#We'll filter and remove these
# Out:
# array(['Natural Chip        Compny SeaSalt175g',
#        'CCs Nacho Cheese    175g',
#        'Smiths Crinkle Cut  Chips Chicken 170g',
#        'Smiths Chip Thinly  S/Cream&Onion 175g',
#        'Kettle Tortilla ChpsHny&Jlpno Chili 150g',
#        'Old El Paso Salsa   Dip Tomato Mild 300g',
#        'Smiths Crinkle Chips Salt & Vinegar 330g',
#        'Grain Waves         Sweet Chilli 210g',
#        'Doritos Corn Chip Mexican Jalapeno 150g',
#        'Grain Waves Sour    Cream&Chives 210G',
#        'Kettle Sensations   Siracha Lime 150g',
#        'Twisties Cheese     270g', 'WW Crinkle Cut      Chicken 175g',
#        'Thins Chips Light&  Tangy 175g', 'CCs Original 175g',
#        'Burger Rings 220g', 'NCC Sour Cream &    Garden Chives 175g',
#        'Doritos Corn Chip Southern Chicken 150g',
#        'Cheezels Cheese Box 125g', 'Smiths Crinkle      Original 330g',
#        'Infzns Crn Crnchers Tangy Gcamole 110g',
#        'Kettle Sea Salt     And Vinegar 175g',
#        'Smiths Chip Thinly  Cut Original 175g', 'Kettle Original 175g',
#        'Red Rock Deli Thai  Chilli&Lime 150g',
#        'Pringles Sthrn FriedChicken 134g', 'Pringles Sweet&Spcy BBQ 134g',
#        'Red Rock Deli SR    Salsa & Mzzrlla 150g',
#        'Thins Chips         Originl saltd 175g',
#        'Red Rock Deli Sp    Salt & Truffle 150G',
#        'Smiths Thinly       Swt Chli&S/Cream175G', 'Kettle Chilli 175g',
#        'Doritos Mexicana    170g',
#        'Smiths Crinkle Cut  French OnionDip 150g',
#        'Natural ChipCo      Hony Soy Chckn175g',
#        'Dorito Corn Chp     Supreme 380g', 'Twisties Chicken270g',
#        'Smiths Thinly Cut   Roast Chicken 175g',
#        'Smiths Crinkle Cut  Tomato Salsa 150g',
#        'Kettle Mozzarella   Basil & Pesto 175g',
#        'Infuzions Thai SweetChili PotatoMix 110g',
#        'Kettle Sensations   Camembert & Fig 150g',
#        'Smith Crinkle Cut   Mac N Cheese 150g',
#        'Kettle Honey Soy    Chicken 175g',
#        'Thins Chips Seasonedchicken 175g',
#        'Smiths Crinkle Cut  Salt & Vinegar 170g',
#        'Infuzions BBQ Rib   Prawn Crackers 110g',
#        'GrnWves Plus Btroot & Chilli Jam 180g',
#        'Tyrrells Crisps     Lightly Salted 165g',
#        'Kettle Sweet Chilli And Sour Cream 175g',
#        'Doritos Salsa       Medium 300g', 'Kettle 135g Swt Pot Sea Salt',
#        'Pringles SourCream  Onion 134g',
#        'Doritos Corn Chips  Original 170g',
#        'Twisties Cheese     Burger 250g',
#        'Old El Paso Salsa   Dip Chnky Tom Ht300g',
#        'Cobs Popd Swt/Chlli &Sr/Cream Chips 110g',
#        'Woolworths Mild     Salsa 300g',
#        'Natural Chip Co     Tmato Hrb&Spce 175g',
#        'Smiths Crinkle Cut  Chips Original 170g',
#        'Cobs Popd Sea Salt  Chips 110g',
#        'Smiths Crinkle Cut  Chips Chs&Onion170g',
#        'French Fries Potato Chips 175g',
#        'Old El Paso Salsa   Dip Tomato Med 300g',
#        'Doritos Corn Chips  Cheese Supreme 170g',
#        'Pringles Original   Crisps 134g',
#        'RRD Chilli&         Coconut 150g',
#        'WW Original Corn    Chips 200g',
#        'Thins Potato Chips  Hot & Spicy 175g',
#        'Cobs Popd Sour Crm  &Chives Chips 110g',
#        'Smiths Crnkle Chip  Orgnl Big Bag 380g',
#        'Doritos Corn Chips  Nacho Cheese 170g',
#        'Kettle Sensations   BBQ&Maple 150g',
#        'WW D/Style Chip     Sea Salt 200g',
#        'Pringles Chicken    Salt Crips 134g',
#        'WW Original Stacked Chips 160g',
#        'Smiths Chip Thinly  CutSalt/Vinegr175g', 'Cheezels Cheese 330g',
#        'Tostitos Lightly    Salted 175g',
#        'Thins Chips Salt &  Vinegar 175g',
#        'Smiths Crinkle Cut  Chips Barbecue 170g', 'Cheetos Puffs 165g',
#        'RRD Sweet Chilli &  Sour Cream 165g',
#        'WW Crinkle Cut      Original 175g',
#        'Tostitos Splash Of  Lime 175g', 'Woolworths Medium   Salsa 300g',
#        'Kettle Tortilla ChpsBtroot&Ricotta 150g',
#        'CCs Tasty Cheese    175g', 'Woolworths Cheese   Rings 190g',
#        'Tostitos Smoked     Chipotle 175g', 'Pringles Barbeque   134g',
#        'WW Supreme Cheese   Corn Chips 200g',
#        'Pringles Mystery    Flavour 134g',
#        'Tyrrells Crisps     Ched & Chives 165g',
#        'Snbts Whlgrn Crisps Cheddr&Mstrd 90g',
#        'Cheetos Chs & Bacon Balls 190g', 'Pringles Slt Vingar 134g',
#        'Infuzions SourCream&Herbs Veg Strws 110g',
#        'Kettle Tortilla ChpsFeta&Garlic 150g',
#        'Infuzions Mango     Chutny Papadums 70g',
#        'RRD Steak &         Chimuchurri 150g',
#        'RRD Honey Soy       Chicken 165g',
#        'Sunbites Whlegrn    Crisps Frch/Onin 90g',
#        'RRD Salt & Vinegar  165g', 'Doritos Cheese      Supreme 330g',
#        'Smiths Crinkle Cut  Snag&Sauce 150g',
#        'WW Sour Cream &OnionStacked Chips 160g',
#        'RRD Lime & Pepper   165g',
#        'Natural ChipCo Sea  Salt & Vinegr 175g',
#        'Red Rock Deli Chikn&Garlic Aioli 150g',
#        'RRD SR Slow Rst     Pork Belly 150g', 'RRD Pc Sea Salt     165g',
#        'Smith Crinkle Cut   Bolognese 150g', 'Doritos Salsa Mild  300g'],
#       dtype=object)

# %%
retail_df1 = retail_df.loc[~(retail_df['PROD_NAME']).str.contains('300g') == True].sort_values('DATE')
retail_df1
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 256685 2018-07-01        245          245339  247845         7
# 235990 2018-07-01        222          222040  221737        42
# 34341  2018-07-01         25           25040   21704        87
# 62583  2018-07-01        128          128215  132006        29
# 116435 2018-07-01        256          256330  255496        52
# ...           ...        ...             ...     ...       ...
# 111308 2019-06-30        172          172209  174057         2
# 31603  2019-06-30        199          199320  198993        24
# 245890 2019-06-30         95           95300   95463        23
# 245590 2019-06-30         91           91076   89519        40
# 209226 2019-06-30        105          105060  105632        73
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES
# 256685        Smiths Crinkle      Original 330g         2       11.4
# 235990  Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 34341   Infuzions BBQ Rib   Prawn Crackers 110g         2        7.6
# 62583            French Fries Potato Chips 175g         2        6.0
# 116435    Grain Waves Sour    Cream&Chives 210G         1        3.6
# ...                                         ...       ...        ...
# 111308   Cobs Popd Sour Crm  &Chives Chips 110g         2        7.6
# 31603     Grain Waves         Sweet Chilli 210g         2        7.2
# 245890                     Cheezels Cheese 330g         2       11.4
# 245590         Thins Chips Seasonedchicken 175g         2        6.6
# 209226  Smiths Crinkle Cut  Salt & Vinegar 170g         2        5.8
#
# [249668 rows x 8 columns]

# %% [markdown]
# I want to do a trend analysis of sales for the two years, over different intervals (Sales per day, Sales per week, sales per month, and sales per quarter

# %%
#Include another column for quarterly period
retail_df1['QTR']=pd.PeriodIndex(retail_df1['DATE'], freq='Q')
retail_df1
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 256685 2018-07-01        245          245339  247845         7
# 235990 2018-07-01        222          222040  221737        42
# 34341  2018-07-01         25           25040   21704        87
# 62583  2018-07-01        128          128215  132006        29
# 116435 2018-07-01        256          256330  255496        52
# ...           ...        ...             ...     ...       ...
# 111308 2019-06-30        172          172209  174057         2
# 31603  2019-06-30        199          199320  198993        24
# 245890 2019-06-30         95           95300   95463        23
# 245590 2019-06-30         91           91076   89519        40
# 209226 2019-06-30        105          105060  105632        73
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES     QTR
# 256685        Smiths Crinkle      Original 330g         2       11.4  2018Q3
# 235990  Doritos Corn Chip Mexican Jalapeno 150g         2        7.8  2018Q3
# 34341   Infuzions BBQ Rib   Prawn Crackers 110g         2        7.6  2018Q3
# 62583            French Fries Potato Chips 175g         2        6.0  2018Q3
# 116435    Grain Waves Sour    Cream&Chives 210G         1        3.6  2018Q3
# ...                                         ...       ...        ...     ...
# 111308   Cobs Popd Sour Crm  &Chives Chips 110g         2        7.6  2019Q2
# 31603     Grain Waves         Sweet Chilli 210g         2        7.2  2019Q2
# 245890                     Cheezels Cheese 330g         2       11.4  2019Q2
# 245590         Thins Chips Seasonedchicken 175g         2        6.6  2019Q2
# 209226  Smiths Crinkle Cut  Salt & Vinegar 170g         2        5.8  2019Q2
#
# [249668 rows x 9 columns]

# %%
retail_df1['QTR'].unique()
# Out:
# <PeriodArray>
# ['2018Q3', '2018Q4', '2019Q1', '2019Q2']
# Length: 4, dtype: period[Q-DEC]

# %%
retail_df1 = retail_df1[['DATE','QTR','STORE_NBR','LYLTY_CARD_NBR','TXN_ID','PROD_NBR','PROD_NAME','PROD_QTY','TOT_SALES']]
retail_df1
# Out:
#              DATE     QTR  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 256685 2018-07-01  2018Q3        245          245339  247845         7
# 235990 2018-07-01  2018Q3        222          222040  221737        42
# 34341  2018-07-01  2018Q3         25           25040   21704        87
# 62583  2018-07-01  2018Q3        128          128215  132006        29
# 116435 2018-07-01  2018Q3        256          256330  255496        52
# ...           ...     ...        ...             ...     ...       ...
# 111308 2019-06-30  2019Q2        172          172209  174057         2
# 31603  2019-06-30  2019Q2        199          199320  198993        24
# 245890 2019-06-30  2019Q2         95           95300   95463        23
# 245590 2019-06-30  2019Q2         91           91076   89519        40
# 209226 2019-06-30  2019Q2        105          105060  105632        73
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES
# 256685        Smiths Crinkle      Original 330g         2       11.4
# 235990  Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 34341   Infuzions BBQ Rib   Prawn Crackers 110g         2        7.6
# 62583            French Fries Potato Chips 175g         2        6.0
# 116435    Grain Waves Sour    Cream&Chives 210G         1        3.6
# ...                                         ...       ...        ...
# 111308   Cobs Popd Sour Crm  &Chives Chips 110g         2        7.6
# 31603     Grain Waves         Sweet Chilli 210g         2        7.2
# 245890                     Cheezels Cheese 330g         2       11.4
# 245590         Thins Chips Seasonedchicken 175g         2        6.6
# 209226  Smiths Crinkle Cut  Salt & Vinegar 170g         2        5.8
#
# [249668 rows x 9 columns]

# %%
#general statistics
retail_df1.describe()
# Out:
#            STORE_NBR  LYLTY_CARD_NBR        TXN_ID       PROD_NBR  \
# count  249668.000000    2.496680e+05  2.496680e+05  249668.000000
# mean      135.044503    1.355205e+05  1.351236e+05      56.294379
# std        76.773857    8.065774e+04  7.813183e+04      33.528877
# min         1.000000    1.000000e+03  1.000000e+00       1.000000
# 25%        70.000000    7.001600e+04  6.757375e+04      27.000000
# 50%       130.000000    1.303600e+05  1.351485e+05      53.000000
# 75%       203.000000    2.030800e+05  2.026342e+05      86.000000
# max       272.000000    2.373711e+06  2.415841e+06     114.000000
#
#             PROD_QTY      TOT_SALES
# count  249668.000000  249668.000000
# mean        1.907762       7.293976
# std         0.657129       3.071806
# min         1.000000       1.700000
# 25%         2.000000       5.700000
# 50%         2.000000       7.400000
# 75%         2.000000       8.800000
# max       200.000000     650.000000

# %%
#Looks like there's a customer who made a purchase of 200 bags, way above the average.

# %%
retail_df1.loc[(retail_df1['PROD_QTY']==200)]
# Out:
#             DATE     QTR  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762 2018-08-19  2018Q3        226          226000  226201         4
# 69763 2019-05-20  2019Q2        226          226000  226210         4
#
#                               PROD_NAME  PROD_QTY  TOT_SALES
# 69762  Dorito Corn Chp     Supreme 380g       200      650.0
# 69763  Dorito Corn Chp     Supreme 380g       200      650.0

# %%
#Let's find out if this customer has made any other puchases except from the two
retail_df1.loc[(retail_df1['LYLTY_CARD_NBR']==226000)]
#We're better off removing this customer as their records are outliers
# Out:
#             DATE     QTR  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762 2018-08-19  2018Q3        226          226000  226201         4
# 69763 2019-05-20  2019Q2        226          226000  226210         4
#
#                               PROD_NAME  PROD_QTY  TOT_SALES
# 69762  Dorito Corn Chp     Supreme 380g       200      650.0
# 69763  Dorito Corn Chp     Supreme 380g       200      650.0

# %%
retail_df2 = retail_df1.drop([retail_df1.index[69762], retail_df1.index[69763]])
retail_df2
# Out:
#              DATE     QTR  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 256685 2018-07-01  2018Q3        245          245339  247845         7
# 235990 2018-07-01  2018Q3        222          222040  221737        42
# 34341  2018-07-01  2018Q3         25           25040   21704        87
# 62583  2018-07-01  2018Q3        128          128215  132006        29
# 116435 2018-07-01  2018Q3        256          256330  255496        52
# ...           ...     ...        ...             ...     ...       ...
# 111308 2019-06-30  2019Q2        172          172209  174057         2
# 31603  2019-06-30  2019Q2        199          199320  198993        24
# 245890 2019-06-30  2019Q2         95           95300   95463        23
# 245590 2019-06-30  2019Q2         91           91076   89519        40
# 209226 2019-06-30  2019Q2        105          105060  105632        73
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES
# 256685        Smiths Crinkle      Original 330g         2       11.4
# 235990  Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 34341   Infuzions BBQ Rib   Prawn Crackers 110g         2        7.6
# 62583            French Fries Potato Chips 175g         2        6.0
# 116435    Grain Waves Sour    Cream&Chives 210G         1        3.6
# ...                                         ...       ...        ...
# 111308   Cobs Popd Sour Crm  &Chives Chips 110g         2        7.6
# 31603     Grain Waves         Sweet Chilli 210g         2        7.2
# 245890                     Cheezels Cheese 330g         2       11.4
# 245590         Thins Chips Seasonedchicken 175g         2        6.6
# 209226  Smiths Crinkle Cut  Salt & Vinegar 170g         2        5.8
#
# [249666 rows x 9 columns]

# %%
#Sales per day
plt.figure(figsize=(15,8))
sales_per_purchase_date = retail_df2.groupby('DATE', as_index=False).TOT_SALES.sum()
ax = sns.lineplot(x="DATE", y="TOT_SALES", data=sales_per_purchase_date)
ax.set_title('Sales per day')
# Out:
# Text(0.5, 1.0, 'Sales per day')

# %%
#sales per week
retail_df2['tot_sales_month'] = retail_df2.DATE.dt.to_period('M').astype(str)

# creating an aggregation
plt.figure(figsize=(15,6))
sales_per_purchase_month = retail_df2.groupby('tot_sales_month', as_index=False).TOT_SALES.sum()
ax = sns.pointplot(x="tot_sales_month", y="TOT_SALES", data=sales_per_purchase_month)
ax.set_title('Sales per month')
# Out:
# Text(0.5, 1.0, 'Sales per month')

# %%
#sales per quarter
sales_per_purchase_qtr = retail_df2.groupby('QTR', as_index=False).TOT_SALES.sum()
ax = sns.pointplot(x="QTR", y="TOT_SALES", data=sales_per_purchase_qtr)
ax.set_title('Sales per qtr')
# Out:
# Text(0.5, 1.0, 'Sales per qtr')

# %%
#Lets's sort the dataframe by sales in each store
sales_per_store = retail_df2.groupby('STORE_NBR', as_index=False).TOT_SALES.sum()
sales_per_store = sales_per_store.sort_values(by ='TOT_SALES',ascending=False)
sales_per_store
# Out:
#      STORE_NBR  TOT_SALES
# 224        226   17844.65
# 87          88   15445.85
# 164        165   15188.35
# 235        237   14830.60
# 39          40   14427.30
# ..         ...        ...
# 91          92       9.20
# 205        206       7.60
# 250        252       7.40
# 10          11       6.70
# 75          76       6.00
#
# [271 rows x 2 columns]

# %%
#Top 15 best selling stores
plt.figure(figsize=(10,8))
ax = sales_per_store.iloc[:15].plot.barh(x='STORE_NBR', y='TOT_SALES')

# %%
retail_df2['PROD_NAME'].unique()
# Out:
# array(['Smiths Crinkle      Original 330g',
#        'Doritos Corn Chip Mexican Jalapeno 150g',
#        'Infuzions BBQ Rib   Prawn Crackers 110g',
#        'French Fries Potato Chips 175g',
#        'Grain Waves Sour    Cream&Chives 210G',
#        'Kettle Honey Soy    Chicken 175g',
#        'Infuzions Thai SweetChili PotatoMix 110g',
#        'Pringles Sthrn FriedChicken 134g',
#        'Kettle Mozzarella   Basil & Pesto 175g',
#        'WW Crinkle Cut      Original 175g', 'Burger Rings 220g',
#        'WW Sour Cream &OnionStacked Chips 160g',
#        'Smiths Thinly       Swt Chli&S/Cream175G',
#        'Kettle Tortilla ChpsFeta&Garlic 150g', 'RRD Pc Sea Salt     165g',
#        'RRD Sweet Chilli &  Sour Cream 165g',
#        'Smith Crinkle Cut   Mac N Cheese 150g',
#        'WW Original Corn    Chips 200g',
#        'Smiths Crinkle Chips Salt & Vinegar 330g',
#        'Grain Waves         Sweet Chilli 210g',
#        'Thins Potato Chips  Hot & Spicy 175g',
#        'Smiths Crnkle Chip  Orgnl Big Bag 380g',
#        'Kettle Sensations   Camembert & Fig 150g',
#        'Tyrrells Crisps     Ched & Chives 165g', 'Twisties Chicken270g',
#        'Kettle Sensations   Siracha Lime 150g', 'Cheezels Cheese 330g',
#        'Doritos Corn Chips  Cheese Supreme 170g',
#        'Pringles Chicken    Salt Crips 134g',
#        'Pringles Original   Crisps 134g',
#        'WW Supreme Cheese   Corn Chips 200g',
#        'Kettle Tortilla ChpsBtroot&Ricotta 150g',
#        'RRD Lime & Pepper   165g', 'Tostitos Lightly    Salted 175g',
#        'Thins Chips Light&  Tangy 175g',
#        'Tostitos Smoked     Chipotle 175g',
#        'Kettle Sensations   BBQ&Maple 150g',
#        'Red Rock Deli Sp    Salt & Truffle 150G',
#        'WW Original Stacked Chips 160g', 'Kettle 135g Swt Pot Sea Salt',
#        'Dorito Corn Chp     Supreme 380g',
#        'Kettle Sea Salt     And Vinegar 175g', 'Cheezels Cheese Box 125g',
#        'Thins Chips Seasonedchicken 175g',
#        'Doritos Corn Chips  Nacho Cheese 170g',
#        'Doritos Corn Chip Southern Chicken 150g',
#        'Smiths Crinkle Cut  French OnionDip 150g',
#        'GrnWves Plus Btroot & Chilli Jam 180g',
#        'Doritos Cheese      Supreme 330g',
#        'Smiths Chip Thinly  Cut Original 175g',
#        'Pringles Barbeque   134g',
#        'Smiths Chip Thinly  CutSalt/Vinegr175g',
#        'Cobs Popd Sour Crm  &Chives Chips 110g',
#        'Twisties Cheese     Burger 250g', 'Pringles Sweet&Spcy BBQ 134g',
#        'CCs Nacho Cheese    175g', 'Twisties Cheese     270g',
#        'Infzns Crn Crnchers Tangy Gcamole 110g',
#        'RRD Chilli&         Coconut 150g', 'Doritos Mexicana    170g',
#        'RRD Honey Soy       Chicken 165g',
#        'Pringles SourCream  Onion 134g', 'Kettle Chilli 175g',
#        'Smiths Chip Thinly  S/Cream&Onion 175g',
#        'Smiths Crinkle Cut  Salt & Vinegar 170g', 'Cheetos Puffs 165g',
#        'Pringles Slt Vingar 134g', 'Kettle Original 175g',
#        'Smiths Crinkle Cut  Chips Chs&Onion170g',
#        'Red Rock Deli SR    Salsa & Mzzrlla 150g',
#        'Thins Chips         Originl saltd 175g',
#        'CCs Tasty Cheese    175g',
#        'Cobs Popd Swt/Chlli &Sr/Cream Chips 110g',
#        'Smiths Crinkle Cut  Chips Chicken 170g',
#        'WW Crinkle Cut      Chicken 175g', 'CCs Original 175g',
#        'Pringles Mystery    Flavour 134g',
#        'Smiths Crinkle Cut  Tomato Salsa 150g',
#        'Kettle Sweet Chilli And Sour Cream 175g',
#        'Natural Chip Co     Tmato Hrb&Spce 175g',
#        'Doritos Corn Chips  Original 170g',
#        'Red Rock Deli Thai  Chilli&Lime 150g',
#        'Smiths Crinkle Cut  Chips Original 170g',
#        'Tyrrells Crisps     Lightly Salted 165g',
#        'Red Rock Deli Chikn&Garlic Aioli 150g',
#        'RRD SR Slow Rst     Pork Belly 150g',
#        'Infuzions SourCream&Herbs Veg Strws 110g',
#        'Thins Chips Salt &  Vinegar 175g',
#        'Woolworths Cheese   Rings 190g', 'Cobs Popd Sea Salt  Chips 110g',
#        'Kettle Tortilla ChpsHny&Jlpno Chili 150g',
#        'Tostitos Splash Of  Lime 175g',
#        'NCC Sour Cream &    Garden Chives 175g',
#        'Smiths Thinly Cut   Roast Chicken 175g',
#        'Natural ChipCo Sea  Salt & Vinegr 175g',
#        'Infuzions Mango     Chutny Papadums 70g',
#        'Smith Crinkle Cut   Bolognese 150g', 'RRD Salt & Vinegar  165g',
#        'RRD Steak &         Chimuchurri 150g',
#        'Sunbites Whlegrn    Crisps Frch/Onin 90g',
#        'Snbts Whlgrn Crisps Cheddr&Mstrd 90g',
#        'Smiths Crinkle Cut  Snag&Sauce 150g',
#        'Cheetos Chs & Bacon Balls 190g',
#        'Smiths Crinkle Cut  Chips Barbecue 170g',
#        'WW D/Style Chip     Sea Salt 200g',
#        'Natural ChipCo      Hony Soy Chckn175g',
#        'Natural Chip        Compny SeaSalt175g'], dtype=object)

# %%
#Let's find out the top 15 highest selling products
sales_per_prod = retail_df2.groupby('PROD_NAME', as_index=False).TOT_SALES.sum()
sales_per_prod = sales_per_prod.sort_values(by ='TOT_SALES',ascending=False)
sales_per_prod
# Out:
#                                     PROD_NAME  TOT_SALES
# 11           Dorito Corn Chp     Supreme 380g    40352.0
# 81     Smiths Crnkle Chip  Orgnl Big Bag 380g    36367.6
# 72   Smiths Crinkle Chips Salt & Vinegar 330g    34804.2
# 31     Kettle Mozzarella   Basil & Pesto 175g    34457.4
# 71          Smiths Crinkle      Original 330g    34302.6
# ..                                        ...        ...
# 106            Woolworths Cheese   Rings 190g     5169.6
# 84       Snbts Whlgrn Crisps Cheddr&Mstrd 90g     5076.2
# 99           WW Crinkle Cut      Chicken 175g     4702.2
# 85   Sunbites Whlegrn    Crisps Frch/Onin 90g     4596.8
# 100         WW Crinkle Cut      Original 175g     4532.2
#
# [107 rows x 2 columns]

# %%
plt.figure(figsize=(8,15))
ax = sales_per_prod.iloc[:15].plot.barh(x='PROD_NAME', y='TOT_SALES')

# %%
#Now lets determine sales by brand

# %%
# I will filter the PRD_NAME column with a list of strings I believe represent a particular brand to create the BRAND column
strings = ['Smith','Dorito','Burger','Infuzions','Kettle','Sunbites','Red Rock Deli',
            'Natural Chip','Pringles','RRD','Thins','Woolworths','Cheetos',
            'Tyrrells','Cobs','Tostitos','Grain Waves','Snbts','NCC',
           'Twisties','CCs','Cheezels','WW','Infzns','GrnWves','French Fries']

# %%
def brand_name(x):
    strings = ['Smith','Dorito','Burger','Infuzions','Kettle','Sunbites','Red Rock Deli',
                                    'Natural Chip','Pringles','RRD','Thins','Woolworths','Cheetos',
                                     'Tyrrells','Cobs','Tostitos','Grain Waves','Snbts','NCC','Twisties','CCs','Cheezels','WW','Infzns','GrnWves','French Fries']
    for item in strings:
        if x.find(item) >=0:
            return item
        
retail_df2['BRAND']=retail_df2['PROD_NAME'].apply(brand_name)
retail_df2
# Out:
#              DATE     QTR  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 256685 2018-07-01  2018Q3        245          245339  247845         7
# 235990 2018-07-01  2018Q3        222          222040  221737        42
# 34341  2018-07-01  2018Q3         25           25040   21704        87
# 62583  2018-07-01  2018Q3        128          128215  132006        29
# 116435 2018-07-01  2018Q3        256          256330  255496        52
# ...           ...     ...        ...             ...     ...       ...
# 111308 2019-06-30  2019Q2        172          172209  174057         2
# 31603  2019-06-30  2019Q2        199          199320  198993        24
# 245890 2019-06-30  2019Q2         95           95300   95463        23
# 245590 2019-06-30  2019Q2         91           91076   89519        40
# 209226 2019-06-30  2019Q2        105          105060  105632        73
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES  \
# 256685        Smiths Crinkle      Original 330g         2       11.4
# 235990  Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 34341   Infuzions BBQ Rib   Prawn Crackers 110g         2        7.6
# 62583            French Fries Potato Chips 175g         2        6.0
# 116435    Grain Waves Sour    Cream&Chives 210G         1        3.6
# ...                                         ...       ...        ...
# 111308   Cobs Popd Sour Crm  &Chives Chips 110g         2        7.6
# 31603     Grain Waves         Sweet Chilli 210g         2        7.2
# 245890                     Cheezels Cheese 330g         2       11.4
# 245590         Thins Chips Seasonedchicken 175g         2        6.6
# 209226  Smiths Crinkle Cut  Salt & Vinegar 170g         2        5.8
#
#        tot_sales_month         BRAND
# 256685         2018-07         Smith
# 235990         2018-07        Dorito
# 34341          2018-07     Infuzions
# 62583          2018-07  French Fries
# 116435         2018-07   Grain Waves
# ...                ...           ...
# 111308         2019-06          Cobs
# 31603          2019-06   Grain Waves
# 245890         2019-06      Cheezels
# 245590         2019-06         Thins
# 209226         2019-06         Smith
#
# [249666 rows x 11 columns]

# %%
retail_df2['BRAND'].unique()
# Out:
# array(['Smith', 'Dorito', 'Infuzions', 'French Fries', 'Grain Waves',
#        'Kettle', 'Pringles', 'WW', 'Burger', 'RRD', 'Thins', 'Tyrrells',
#        'Twisties', 'Cheezels', 'Tostitos', 'Red Rock Deli', 'GrnWves',
#        'Cobs', 'CCs', 'Infzns', 'Cheetos', 'Natural Chip', 'Woolworths',
#        'NCC', 'Sunbites', 'Snbts'], dtype=object)

# %%
#Some brand have been repeated since they had short strings like WW and GrnWvs. We'll replace these with the one or either

retail_df2['BRAND'] = retail_df2['BRAND'].replace(['WW'],['Woolworths'])
retail_df2['BRAND'] = retail_df2['BRAND'].replace(['RRD'],['Red Rock Deli'])
retail_df2['BRAND'] = retail_df2['BRAND'].replace(['Infzns'],['Infuzions'])
retail_df2['BRAND'] = retail_df2['BRAND'].replace(['GrnWves'],['Grain Waves'])
retail_df2['BRAND'] = retail_df2['BRAND'].replace(['Snbts'],['Sunbites'])
retail_df2['BRAND'] = retail_df2['BRAND'].replace(['NCC'],['Natural Chip'])
retail_df2
# Out:
#              DATE     QTR  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 256685 2018-07-01  2018Q3        245          245339  247845         7
# 235990 2018-07-01  2018Q3        222          222040  221737        42
# 34341  2018-07-01  2018Q3         25           25040   21704        87
# 62583  2018-07-01  2018Q3        128          128215  132006        29
# 116435 2018-07-01  2018Q3        256          256330  255496        52
# ...           ...     ...        ...             ...     ...       ...
# 111308 2019-06-30  2019Q2        172          172209  174057         2
# 31603  2019-06-30  2019Q2        199          199320  198993        24
# 245890 2019-06-30  2019Q2         95           95300   95463        23
# 245590 2019-06-30  2019Q2         91           91076   89519        40
# 209226 2019-06-30  2019Q2        105          105060  105632        73
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES  \
# 256685        Smiths Crinkle      Original 330g         2       11.4
# 235990  Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 34341   Infuzions BBQ Rib   Prawn Crackers 110g         2        7.6
# 62583            French Fries Potato Chips 175g         2        6.0
# 116435    Grain Waves Sour    Cream&Chives 210G         1        3.6
# ...                                         ...       ...        ...
# 111308   Cobs Popd Sour Crm  &Chives Chips 110g         2        7.6
# 31603     Grain Waves         Sweet Chilli 210g         2        7.2
# 245890                     Cheezels Cheese 330g         2       11.4
# 245590         Thins Chips Seasonedchicken 175g         2        6.6
# 209226  Smiths Crinkle Cut  Salt & Vinegar 170g         2        5.8
#
#        tot_sales_month         BRAND
# 256685         2018-07         Smith
# 235990         2018-07        Dorito
# 34341          2018-07     Infuzions
# 62583          2018-07  French Fries
# 116435         2018-07   Grain Waves
# ...                ...           ...
# 111308         2019-06          Cobs
# 31603          2019-06   Grain Waves
# 245890         2019-06      Cheezels
# 245590         2019-06         Thins
# 209226         2019-06         Smith
#
# [249666 rows x 11 columns]

# %%
retail_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249666 entries, 256685 to 209226
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   DATE             249666 non-null  datetime64[ns]
#  1   QTR              249666 non-null  period[Q-DEC]
#  2   STORE_NBR        249666 non-null  int64
#  3   LYLTY_CARD_NBR   249666 non-null  int64
#  4   TXN_ID           249666 non-null  int64
#  5   PROD_NBR         249666 non-null  int64
#  6   PROD_NAME        249666 non-null  object
#  7   PROD_QTY         249666 non-null  int64
#  8   TOT_SALES        249666 non-null  float64
#  9   tot_sales_month  249666 non-null  object
#  10  BRAND            249666 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3), period[Q-DEC](1)
# memory usage: 22.9+ MB

# %%
retail_df2['BRAND'].unique()
# Out:
# array(['Smith', 'Dorito', 'Infuzions', 'French Fries', 'Grain Waves',
#        'Kettle', 'Pringles', 'Woolworths', 'Burger', 'Red Rock Deli',
#        'Thins', 'Tyrrells', 'Twisties', 'Cheezels', 'Tostitos', 'Cobs',
#        'CCs', 'Cheetos', 'Natural Chip', 'Sunbites'], dtype=object)

# %%
#Now let's determine sales by Brand
sales_per_brand = retail_df2.groupby('BRAND', as_index=False).TOT_SALES.sum()
sales_per_brand = sales_per_brand.sort_values(by ='TOT_SALES',ascending=False)
sales_per_brand
# Out:
#             BRAND  TOT_SALES
# 9          Kettle   390239.8
# 5          Dorito   227629.9
# 13          Smith   224648.2
# 11       Pringles   177655.5
# 8       Infuzions    99047.6
# 12  Red Rock Deli    95046.0
# 15          Thins    88845.9
# 16       Tostitos    79789.6
# 4            Cobs    70569.8
# 17       Twisties    55425.4
# 18       Tyrrells    51647.4
# 7     Grain Waves    51617.2
# 10   Natural Chip    42318.0
# 19     Woolworths    41059.1
# 3        Cheezels    40029.9
# 0          Burger    32927.7
# 1             CCs    18078.9
# 2         Cheetos    16884.5
# 14       Sunbites     9673.0
# 6    French Fries     7929.0

# %%
ax = sales_per_brand.plot.barh(x='BRAND', y='TOT_SALES')

# %%
customers = pd.read_csv(r"E:\My Python codes\QVI_purchase_behaviour.csv")
customers
# Out:
#        LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0                1000   YOUNG SINGLES/COUPLES          Premium
# 1                1002   YOUNG SINGLES/COUPLES       Mainstream
# 2                1003          YOUNG FAMILIES           Budget
# 3                1004   OLDER SINGLES/COUPLES       Mainstream
# 4                1005  MIDAGE SINGLES/COUPLES       Mainstream
# ...               ...                     ...              ...
# 72632         2370651  MIDAGE SINGLES/COUPLES       Mainstream
# 72633         2370701          YOUNG FAMILIES       Mainstream
# 72634         2370751          YOUNG FAMILIES          Premium
# 72635         2370961          OLDER FAMILIES           Budget
# 72636         2373711   YOUNG SINGLES/COUPLES       Mainstream
#
# [72637 rows x 3 columns]

# %%
retail_df3 = pd.merge(retail_df2, customers, how='outer')
retail_df3
# Out:
#              DATE     QTR  STORE_NBR  LYLTY_CARD_NBR    TXN_ID  PROD_NBR  \
# 0      2018-07-01  2018Q3      245.0          245339  247845.0       7.0
# 1      2018-07-01  2018Q3      222.0          222040  221737.0      42.0
# 2      2018-07-01  2018Q3       25.0           25040   21704.0      87.0
# 3      2018-07-01  2018Q3      128.0          128215  132006.0      29.0
# 4      2018-07-19  2018Q3      128.0          128215  132007.0      26.0
# ...           ...     ...        ...             ...       ...       ...
# 250780        NaT     NaT        NaN          272164       NaN       NaN
# 250781        NaT     NaT        NaN          272276       NaN       NaN
# 250782        NaT     NaT        NaN          272295       NaN       NaN
# 250783        NaT     NaT        NaN          272321       NaN       NaN
# 250784        NaT     NaT        NaN          880551       NaN       NaN
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES  \
# 0             Smiths Crinkle      Original 330g       2.0       11.4
# 1       Doritos Corn Chip Mexican Jalapeno 150g       2.0        7.8
# 2       Infuzions BBQ Rib   Prawn Crackers 110g       2.0        7.6
# 3                French Fries Potato Chips 175g       2.0        6.0
# 4                  Pringles Sweet&Spcy BBQ 134g       2.0        7.4
# ...                                         ...       ...        ...
# 250780                                      NaN       NaN        NaN
# 250781                                      NaN       NaN        NaN
# 250782                                      NaN       NaN        NaN
# 250783                                      NaN       NaN        NaN
# 250784                                      NaN       NaN        NaN
#
#        tot_sales_month         BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0              2018-07         Smith  YOUNG SINGLES/COUPLES       Mainstream
# 1              2018-07        Dorito  YOUNG SINGLES/COUPLES           Budget
# 2              2018-07     Infuzions         OLDER FAMILIES           Budget
# 3              2018-07  French Fries         OLDER FAMILIES       Mainstream
# 4              2018-07      Pringles         OLDER FAMILIES       Mainstream
# ...                ...           ...                    ...              ...
# 250780             NaN           NaN         YOUNG FAMILIES       Mainstream
# 250781             NaN           NaN         YOUNG FAMILIES           Budget
# 250782             NaN           NaN               RETIREES       Mainstream
# 250783             NaN           NaN  OLDER SINGLES/COUPLES          Premium
# 250784             NaN           NaN  OLDER SINGLES/COUPLES          Premium
#
# [250785 rows x 13 columns]

# %%
retail_df3.info()
#Looks like there are customers who didn't make any purchases, we'll go ahead and drop these rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250785 entries, 0 to 250784
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DATE              249666 non-null  datetime64[ns]
#  1   QTR               249666 non-null  period[Q-DEC]
#  2   STORE_NBR         249666 non-null  float64
#  3   LYLTY_CARD_NBR    250785 non-null  int64
#  4   TXN_ID            249666 non-null  float64
#  5   PROD_NBR          249666 non-null  float64
#  6   PROD_NAME         249666 non-null  object
#  7   PROD_QTY          249666 non-null  float64
#  8   TOT_SALES         249666 non-null  float64
#  9   tot_sales_month   249666 non-null  object
#  10  BRAND             249666 non-null  object
#  11  LIFESTAGE         250785 non-null  object
#  12  PREMIUM_CUSTOMER  250785 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(5), period[Q-DEC](1)
# memory usage: 26.8+ MB

# %%
retail_df3.dropna(axis=0, how='any',inplace=True)

# %% [markdown]
# We will try to find out the following
# - Who spends the most on chips (total sales), describing customers by lifestage and
# how premium their general purchasing behaviour is
# - How many customers are in each segment
# - How many chips are bought per customer by segment
# - What's the average chip price by customer segment

# %%
retail_df3
# Out:
#              DATE     QTR  STORE_NBR  LYLTY_CARD_NBR    TXN_ID  PROD_NBR  \
# 0      2018-07-01  2018Q3      245.0          245339  247845.0       7.0
# 1      2018-07-01  2018Q3      222.0          222040  221737.0      42.0
# 2      2018-07-01  2018Q3       25.0           25040   21704.0      87.0
# 3      2018-07-01  2018Q3      128.0          128215  132006.0      29.0
# 4      2018-07-19  2018Q3      128.0          128215  132007.0      26.0
# ...           ...     ...        ...             ...       ...       ...
# 249661 2019-06-30  2019Q2      256.0          256274  255436.0     106.0
# 249662 2019-06-30  2019Q2      255.0          255079  254624.0     113.0
# 249663 2019-06-30  2019Q2      214.0          214164  213762.0      71.0
# 249664 2019-06-30  2019Q2        6.0            6358    6145.0      87.0
# 249665 2019-06-30  2019Q2      240.0          240071  244101.0      17.0
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES  \
# 0             Smiths Crinkle      Original 330g       2.0       11.4
# 1       Doritos Corn Chip Mexican Jalapeno 150g       2.0        7.8
# 2       Infuzions BBQ Rib   Prawn Crackers 110g       2.0        7.6
# 3                French Fries Potato Chips 175g       2.0        6.0
# 4                  Pringles Sweet&Spcy BBQ 134g       2.0        7.4
# ...                                         ...       ...        ...
# 249661   Natural ChipCo      Hony Soy Chckn175g       2.0        6.0
# 249662                     Twisties Chicken270g       1.0        4.6
# 249663          Twisties Cheese     Burger 250g       1.0        4.3
# 249664  Infuzions BBQ Rib   Prawn Crackers 110g       1.0        3.8
# 249665       Kettle Sensations   BBQ&Maple 150g       2.0        9.2
#
#        tot_sales_month         BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0              2018-07         Smith  YOUNG SINGLES/COUPLES       Mainstream
# 1              2018-07        Dorito  YOUNG SINGLES/COUPLES           Budget
# 2              2018-07     Infuzions         OLDER FAMILIES           Budget
# 3              2018-07  French Fries         OLDER FAMILIES       Mainstream
# 4              2018-07      Pringles         OLDER FAMILIES       Mainstream
# ...                ...           ...                    ...              ...
# 249661         2019-06  Natural Chip  OLDER SINGLES/COUPLES          Premium
# 249662         2019-06      Twisties  OLDER SINGLES/COUPLES          Premium
# 249663         2019-06        Burger               RETIREES           Budget
# 249664         2019-06     Infuzions  YOUNG SINGLES/COUPLES          Premium
# 249665         2019-06        Kettle               RETIREES       Mainstream
#
# [249666 rows x 13 columns]

# %%
#Let's see sales by customer lifestage
sales_by_lifestage = retail_df3.groupby('LIFESTAGE', as_index=False).TOT_SALES.sum()
sales_by_lifestage = sales_by_lifestage.sort_values(by ='TOT_SALES',ascending=False)
sales_by_lifestage
# Out:
#                 LIFESTAGE  TOT_SALES
# 3   OLDER SINGLES/COUPLES  378871.95
# 4                RETIREES  344886.90
# 2          OLDER FAMILIES  332943.80
# 5          YOUNG FAMILIES  297386.00
# 6   YOUNG SINGLES/COUPLES  245307.50
# 0  MIDAGE SINGLES/COUPLES  174010.50
# 1            NEW FAMILIES   47655.75

# %%
ax1 = sales_by_lifestage.plot.barh(x='LIFESTAGE', y='TOT_SALES')
#Older single/Couples spend most on chips

# %%
retail_df3['PREMIUM_CUSTOMER'].unique()
# Out:
# array(['Mainstream', 'Budget', 'Premium'], dtype=object)

# %%
sales_by_premium = retail_df3.groupby('PREMIUM_CUSTOMER', as_index=False).TOT_SALES.sum()
sales_by_premium = sales_by_premium.sort_values(by ='TOT_SALES',ascending=False)
sales_by_premium
# Out:
#   PREMIUM_CUSTOMER  TOT_SALES
# 1       Mainstream  706242.50
# 0           Budget  636632.85
# 2          Premium  478187.05

# %%
ax2 = sales_by_premium.plot.bar(x='PREMIUM_CUSTOMER', y='TOT_SALES')
#Mainstream customers spend the most on chips

# %%
plt.figure(figsize=(15,6))
S = sns.countplot(x="LIFESTAGE", hue="PREMIUM_CUSTOMER", data=retail_df3)

# %% [markdown]
# Average sales by Lifestage

# %%
avg_sale_per_lifestage = retail_df3.groupby('LIFESTAGE', as_index=False).agg({'TOT_SALES': ['count','mean']})
avg_sale_per_lifestage.columns = ['TOT_SALES', 'count', 'mean']

avg_sale_per_lifestage = avg_sale_per_lifestage.sort_values(by='mean', ascending=False)
avg_sale_per_lifestage
# Out:
#                 TOT_SALES  count      mean
# 3   OLDER SINGLES/COUPLES  51361  7.376647
# 4                RETIREES  46934  7.348338
# 0  MIDAGE SINGLES/COUPLES  23700  7.342215
# 2          OLDER FAMILIES  45767  7.274757
# 1            NEW FAMILIES   6562  7.262382
# 5          YOUNG FAMILIES  41033  7.247484
# 6   YOUNG SINGLES/COUPLES  34309  7.149946

# %% [markdown]
# Average product Qty by lifestage

# %%
avg_sale_per_lifestage1 = retail_df3.groupby('LIFESTAGE', as_index=False).agg({'PROD_QTY': ['count','mean']})
avg_sale_per_lifestage1.columns = ['PROD_QTY', 'count', 'mean']

avg_sale_per_lifestage1 = avg_sale_per_lifestage1.sort_values(by='mean', ascending=False)
avg_sale_per_lifestage1
# Out:
#                  PROD_QTY  count      mean
# 2          OLDER FAMILIES  45767  1.955011
# 5          YOUNG FAMILIES  41033  1.940341
# 3   OLDER SINGLES/COUPLES  51361  1.913164
# 0  MIDAGE SINGLES/COUPLES  23700  1.901181
# 4                RETIREES  46934  1.892423
# 1            NEW FAMILIES   6562  1.857056
# 6   YOUNG SINGLES/COUPLES  34309  1.832901

# %% [markdown]
# Let's do RFM Analysis by each customer

# %%
import warnings
warnings.filterwarnings('ignore')
from datetime import timedelta

# %%
temp=['LYLTY_CARD_NBR', 'TXN_ID', 'DATE', 'TOT_SALES']
RFM_data=retail_df3[temp]
RFM_data.shape
# Out:
# (249666, 4)

# %%
RFM_data.head()
# Out:
#    LYLTY_CARD_NBR    TXN_ID       DATE  TOT_SALES
# 0          245339  247845.0 2018-07-01       11.4
# 1          222040  221737.0 2018-07-01        7.8
# 2           25040   21704.0 2018-07-01        7.6
# 3          128215  132006.0 2018-07-01        6.0
# 4          128215  132007.0 2018-07-19        7.4

# %%
RFM_table=RFM_data.groupby('LYLTY_CARD_NBR')

# %%
#create an instance from the most recent date of purchase
now_date = retail_df3['DATE'].max() + timedelta(days=1)
now_date
# Out:
# Timestamp('2019-07-01 00:00:00')

# %%
RFM_table = RFM_data.groupby(['LYLTY_CARD_NBR']).agg({'DATE': lambda x: (now_date - x.max()).days,
                                                 'TXN_ID': lambda x: len(x.unique()),
                                                 'TOT_SALES': lambda x: x.sum()})
RFM_table['DATE'] = RFM_table['DATE'].astype(int)
RFM_table.rename(columns={'DATE': 'recency', 
                         'TXN_ID': 'frequency',
                         'TOT_SALES': 'monetary_value'}, inplace=True)

#Let's sort by frequency to see which customers make the most visits
RFM_table1 = RFM_table.sort_values(by=['frequency'],ascending=False)
RFM_table1.head(20)
# Out:
#                 recency  frequency  monetary_value
# LYLTY_CARD_NBR
# 162039               10       18.0           126.8
# 230078               11       17.0           138.6
# 105026               14       16.0           114.2
# 179228                3       16.0           120.8
# 113080               11       15.0           107.8
# 156240               20       15.0            86.2
# 207003               13       15.0           107.2
# 213140                1       15.0           108.2
# 116181                4       15.0           112.4
# 129050               18       15.0            93.5
# 104117                5       15.0           106.6
# 152054               95       15.0            99.8
# 128178                9       15.0            96.7
# 30162                13       15.0            99.6
# 138016               26       15.0           103.6
# 94185                37       15.0           112.6
# 222242                2       15.0           104.0
# 109036               11       15.0           113.0
# 28020                 1       15.0           115.6
# 23192               132       15.0           114.7

# %%
#Let's plot a distribution of the three characteristics in a histogram
RFM_table1['frequency'].hist(bins=10)

# %%
RFM_table1['recency'].hist(bins=20)

# %%
RFM_table1['monetary_value'].hist(bins=50)

# %%
All three clearly show a right skew distribution.
