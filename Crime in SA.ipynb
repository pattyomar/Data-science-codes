# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\My Python codes\SouthAfricaCrimeStats_v2.csv')
df
# Out:
#            Province            Station                           Category  \
# 0      Western Cape  Cape Town Central  All theft not mentioned elsewhere
# 1           Gauteng        Jhb Central  All theft not mentioned elsewhere
# 2      Western Cape    Mitchells Plain  All theft not mentioned elsewhere
# 3        Free State          Park Road  All theft not mentioned elsewhere
# 4           Gauteng   Pretoria Central  All theft not mentioned elsewhere
# ...             ...                ...                                ...
# 30856  Western Cape             Belhar  All theft not mentioned elsewhere
# 30857       Gauteng         Moffatview  All theft not mentioned elsewhere
# 30858  Western Cape             Belhar                 Drug-related crime
# 30859  Western Cape          Lentegeur  All theft not mentioned elsewhere
# 30860  Western Cape          Lentegeur                 Drug-related crime
#
#        2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# ...

# %%
#to check for null values, no null values found
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30861 entries, 0 to 30860
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Province   30861 non-null  object
#  1   Station    30861 non-null  object
#  2   Category   30861 non-null  object
#  3   2005-2006  30861 non-null  int64
#  4   2006-2007  30861 non-null  int64
#  5   2007-2008  30861 non-null  int64
#  6   2008-2009  30861 non-null  int64
#  7   2009-2010  30861 non-null  int64
#  8   2010-2011  30861 non-null  int64
#  9   2011-2012  30861 non-null  int64
#  10  2012-2013  30861 non-null  int64
#  11  2013-2014  30861 non-null  int64
#  12  2014-2015  30861 non-null  int64
#  13  2015-2016  30861 non-null  int64
# dtypes: int64(11), object(3)
# memory usage: 3.3+ MB

# %%
print(list(df['Province'].unique()))
print(df['Station'].unique())
print(df['Category'].unique())
# Out:
# ['Western Cape', 'Gauteng', 'Free State', 'North West', 'Kwazulu/Natal', 'Mpumalanga', 'Eastern Cape', 'Limpopo', 'Northern Cape']
# ['Cape Town Central' 'Jhb Central' 'Mitchells Plain' ... 'Belhar'
#  'Lentegeur' 'Lwandle']
# ['All theft not mentioned elsewhere' 'Theft out of or from motor vehicle'
#  'Drug-related crime' 'Robbery with aggravating circumstances'
#  'Common assault' 'Commercial crime' 'Burglary at residential premises'
#  'Assault with the intent to inflict grievous bodily harm'
#  'Theft of motor vehicle and motorcycle' 'Shoplifting'
#  'Malicious damage to property' 'Common robbery'
#  'Burglary at non-residential premises' 'Sexual Offences'
#  'Driving under the influence of alcohol or drugs' 'Stock-theft'
#  'Attempted murder' 'Carjacking' 'Robbery at non-residential premises'
#  'Robbery at residential premises' 'Murder'
#  'Illegal possession of firearms and ammunition' 'Arson' 'Truck hijacking'
#  'Robbery of cash in transit' 'Bank robbery'
# ...

# %%
df_province = df.groupby(['Province']).sum()
df_province
# Out:
#                2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  \
# Province
# Eastern Cape      238977     228884     220813     216658     217230
# Free State        137987     128227     127955     132335     127512
# Gauteng           654817     639635     615618     638186     640074
# Kwazulu/Natal     345784     343798     328368     340095     349103
# Limpopo           106983     104857      97166      97565      99610
# Mpumalanga        134829     131444     125954     131410     128814
# North West        118840     112471     112340     117118     115680
# Northern Cape      56515      52689      48954      50277      49746
# Western Cape      381825     396712     395281     398240     417619
#
#                2010-2011  2011-2012  2012-2013  2013-2014  2014-2015  \
# Province
# Eastern Cape      215012     214462     209124     210248     202582
# Free State        121997     126389     131785     126290     118879
# ...

# %%
df_province.transpose().describe().round(0)
# Out:
# Province  Eastern Cape  Free State   Gauteng  Kwazulu/Natal   Limpopo  \
# count             11.0        11.0      11.0           11.0      11.0
# mean          215462.0    127004.0  623241.0       346263.0  109199.0
# std            11731.0      5944.0   24409.0         8713.0   11476.0
# min           196089.0    117688.0  577959.0       328368.0   96475.0
# 25%           209686.0    124144.0  612462.0       343270.0   98588.0
# 50%           215012.0    127512.0  636195.0       345784.0  106983.0
# 75%           219022.0    130006.0  638910.0       348757.0  115634.0
# max           238977.0    137987.0  654817.0       362677.0  129323.0
#
# Province  Mpumalanga  North West  Northern Cape  Western Cape
# count           11.0        11.0           11.0          11.0
# mean        124630.0    114114.0        49660.0      435648.0
# std           6280.0      2614.0         3134.0       41306.0
# min         115996.0    109922.0        45257.0      381825.0
# ...

# %%
df_province.plot(kind='bar', rot=80)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=1)
plt.title('Crime per province')
#Graph to show provinces with highest crime rates
# Out:
# Text(0.5, 1.0, 'Crime per province')

# %%
df_province.plot(kind='bar', figsize = (8, 50), subplots = True, rot=80)
plt.legend()
plt.title('Crime per province')
# Out:
# Text(0.5, 1.0, 'Crime per province')

# %%
df_crimes = df.groupby(['Category']).sum()
df_crimes
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                      424690     407714
# Arson                                                    7247       7438
# Assault with the intent to inflict grievous bod...     225659     216754
# Attempted murder                                        20369      19957
# Bank robbery                                               59        130
# Burglary at non-residential premises                    54217      58240
# Burglary at residential premises                       261403     248462
# Carjacking                                              12783      13534
# Commercial crime                                        51911      59637
# Common assault                                         225436     207869
# Common robbery                                          74221      70598
# Driving under the influence of alcohol or drugs         33076      38210
# ...

# %%
df_crimes.plot(kind='bar', figsize = (15, 6), rot=90)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.title('Common crimes')
#Graph to show most common crimes in SA
# Out:
# Text(0.5, 1.0, 'Common crimes')

# %%
df_crimes.plot(kind='bar', figsize = (10, 50), subplots = True, rot=90)
plt.legend()
plt.title('Common crimes')
# Out:
# Text(0.5, 1.0, 'Common crimes')

# %%
western_cape = df[df["Province"]=="Western Cape"]
gauteng = df[df["Province"]=="Gauteng"]
free_state = df[df["Province"]=="Free State"]
n_west = df[df["Province"]=="North West"]
kwazulu = df[df["Province"]=="Kwazulu/Natal"]
mpumalanga = df[df["Province"]=="Mpumalanga"]
eastern_cape = df[df["Province"]=="Eastern Cape"]
limpopo = df[df["Province"]=="Limpopo"]
northern_cape = df[df["Province"]=="Northern Cape"]

# %%
western_cape = df[df["Province"]=="Western Cape"].sum
western_cape
# Out:
#            Province            Station                            Category  \
# 0      Western Cape  Cape Town Central   All theft not mentioned elsewhere
# 2      Western Cape    Mitchells Plain   All theft not mentioned elsewhere
# 11     Western Cape  Cape Town Central  Theft out of or from motor vehicle
# 12     Western Cape    Mitchells Plain                  Drug-related crime
# 14     Western Cape          Bellville   All theft not mentioned elsewhere
# ...             ...                ...                                 ...
# 30848  Western Cape          Lentegeur    Burglary at residential premises
# 30856  Western Cape             Belhar   All theft not mentioned elsewhere
# 30858  Western Cape             Belhar                  Drug-related crime
# 30859  Western Cape          Lentegeur   All theft not mentioned elsewhere
# 30860  Western Cape          Lentegeur                  Drug-related crime
#
# ...

# %%
common_crime = western_cape.groupby(['Category']).sum()
common_crime
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                       88481      91954
# Arson                                                     568        607
# Assault with the intent to inflict grievous bod...      28356      25800
# Attempted murder                                         1832       2028
# Bank robbery                                                1          5
# Burglary at non-residential premises                     7918      10090
# Burglary at residential premises                        40837      43011
# Carjacking                                                961        903
# Commercial crime                                         6730       7549
# Common assault                                          37982      34862
# Common robbery                                           9343       8651
# Driving under the influence of alcohol or drugs          8110       9569
# ...

# %%
common_crime.plot(kind='bar', figsize = (15, 6), rot=90)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.title('Common crimes in Western cape')
# Out:
# Text(0.5, 1.0, 'Common crimes in Western cape')

# %%
cc_pct = common_crime.pct_change(axis = 'columns' ).fillna(0).round(3)
cc_pct
#to claculate percentage change between columns
#remove the'axis' parameter to calculate % change between rows
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                         0.0      0.039
# Arson                                                     0.0      0.069
# Assault with the intent to inflict grievous bod...        0.0     -0.090
# Attempted murder                                          0.0      0.107
# Bank robbery                                              0.0      4.000
# Burglary at non-residential premises                      0.0      0.274
# Burglary at residential premises                          0.0      0.053
# Carjacking                                                0.0     -0.060
# Commercial crime                                          0.0      0.122
# Common assault                                            0.0     -0.082
# Common robbery                                            0.0     -0.074
# Driving under the influence of alcohol or drugs           0.0      0.180
# ...

# %%
cc_pct1 = cc_pct.transpose()
cc_pct1
# Out:
# Category   All theft not mentioned elsewhere  Arson  \
# 2005-2006                              0.000  0.000
# 2006-2007                              0.039  0.069
# 2007-2008                             -0.024 -0.016
# 2008-2009                             -0.002 -0.146
# 2009-2010                             -0.045  0.122
# 2010-2011                             -0.018  0.070
# 2011-2012                              0.092  0.083
# 2012-2013                             -0.012  0.042
# 2013-2014                              0.037 -0.061
# 2014-2015                              0.036  0.205
# 2015-2016                             -0.055 -0.032
#
# Category   Assault with the intent to inflict grievous bodily harm  \
# 2005-2006                                              0.000
# 2006-2007                                             -0.090
# 2007-2008                                             -0.037
# 2008-2009                                             -0.073
# ...

# %%
cc_pct1.plot(kind='line', figsize = (25, 6), rot=90)
plt.legend(ncol = 3)
plt.title('change over the years')
#Graph to show percentage change in different crimes over the years in Western Cape Province
# Out:
# Text(0.5, 1.0, 'change over the years')

# %%
cc_pct1.plot(kind='line', figsize = (10, 50), subplots = True, rot=90)
plt.legend()
plt.title('change over the years')
# Out:
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
# ...

# %%
gauteng = df[df["Province"]=="Gauteng"]
gauteng
# Out:
#       Province           Station  \
# 1      Gauteng       Jhb Central
# 4      Gauteng  Pretoria Central
# 7      Gauteng          Brooklyn
# 8      Gauteng          Booysens
# 9      Gauteng          Hillbrow
# ...        ...               ...
# 30847  Gauteng  Olievenhoutbosch
# 30849  Gauteng     Mamelodi East
# 30853  Gauteng     Mamelodi East
# 30854  Gauteng         Diepsloot
# 30857  Gauteng        Moffatview
#
#                                                 Category  2005-2006  \
# 1                      All theft not mentioned elsewhere       6093
# 4                      All theft not mentioned elsewhere       5099
# 7                      All theft not mentioned elsewhere       3931
# 8                      All theft not mentioned elsewhere       3681
# 9                      All theft not mentioned elsewhere       3489
# ...                                                  ...        ...
# 30847                  All theft not mentioned elsewhere          0
# ...

# %%
common_crimeG = gauteng.groupby(['Category']).sum()
common_crimeG
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                      134063     128732
# Arson                                                    1886       1954
# Assault with the intent to inflict grievous bod...      50891      49688
# Attempted murder                                         5706       5690
# Bank robbery                                               46         82
# Burglary at non-residential premises                    13252      14682
# Burglary at residential premises                        74990      67643
# Carjacking                                               7236       7320
# Commercial crime                                        23379      25980
# Common assault                                          62130      58141
# Common robbery                                          25351      25148
# Driving under the influence of alcohol or drugs          7266       7528
# ...

# %%
common_crimeG.plot(kind='bar', figsize = (15, 6), rot=90)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.title('Common crimes in Gauteng')
# Out:
# Text(0.5, 1.0, 'Common crimes in Gauteng')

# %%
free_state = df[df["Province"]=="Free State"]
free_state
# Out:
#          Province    Station  \
# 3      Free State  Park Road
# 33     Free State     Welkom
# 53     Free State  Park Road
# 137    Free State    Thabong
# 147    Free State  Park Road
# ...           ...        ...
# 30808  Free State    Zamdela
# 30820  Free State    Zamdela
# 30823  Free State    Zamdela
# 30828  Free State    Zamdela
# 30852  Free State    Zamdela
#
#                                                 Category  2005-2006  \
# 3                      All theft not mentioned elsewhere       5108
# 33                     All theft not mentioned elsewhere       2173
# 53                    Theft out of or from motor vehicle       1910
# 137                                       Common assault       1330
# 147                                       Common assault       1315
# ...                                                  ...        ...
# 30808                  All theft not mentioned elsewhere          0
# ...

# %%
common_crimeFS = free_state.groupby(['Category']).sum()
common_crimeFS
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                       26602      23331
# Arson                                                     396        418
# Assault with the intent to inflict grievous bod...      16796      15856
# Attempted murder                                         1032        979
# Bank robbery                                                1          5
# Burglary at non-residential premises                     4087       4082
# Burglary at residential premises                        17353      15939
# Carjacking                                                 92        120
# Commercial crime                                         2229       2157
# Common assault                                          22179      19572
# Common robbery                                           4039       4146
# Driving under the influence of alcohol or drugs          1320       1246
# ...

# %%
common_crimeFS.plot(kind='bar', figsize = (15, 6), rot=90)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.title('Common crimes in Free State')
# Out:
# Text(0.5, 1.0, 'Common crimes in Free State')

# %%
n_west = df[df["Province"]=="North West"]
n_west
# Out:
#          Province        Station  \
# 5      North West     Rustenburg
# 22     North West     Klerksdorp
# 26     North West  Potchefstroom
# 62     North West     Rustenburg
# 117    North West          Brits
# ...           ...            ...
# 30694  North West         Hebron
# 30717  North West         Huhudi
# 30764  North West         Hebron
# 30765  North West         Hebron
# 30802  North West         Huhudi
#
#                                                 Category  2005-2006  \
# 5                      All theft not mentioned elsewhere       4239
# 22                     All theft not mentioned elsewhere       2511
# 26                     All theft not mentioned elsewhere       2424
# 62                      Burglary at residential premises       1807
# 117                    All theft not mentioned elsewhere       1405
# ...                                                  ...        ...
# 30694                  All theft not mentioned elsewhere          0
# ...

# %%
common_crimeNW = n_west.groupby(['Category']).sum()
common_crimeNW
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                       24125      22414
# Arson                                                     455        501
# Assault with the intent to inflict grievous bod...      15468      15081
# Attempted murder                                          837        814
# Bank robbery                                                0          8
# Burglary at non-residential premises                     4289       4315
# Burglary at residential premises                        15463      13684
# Carjacking                                                223        260
# Commercial crime                                         2152       2277
# Common assault                                          11390      10152
# Common robbery                                           4039       3380
# Driving under the influence of alcohol or drugs          1780       1901
# ...

# %%
common_crimeNW.plot(kind='bar', figsize = (15, 6), rot=90)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.title('Common crimes in North Western')
# Out:
# Text(0.5, 1.0, 'Common crimes in North Western')

# %%
kwazulu = df[df["Province"]=="Kwazulu/Natal"]
kwazulu
# Out:
#             Province         Station  \
# 6      Kwazulu/Natal  Durban Central
# 17     Kwazulu/Natal  Durban Central
# 34     Kwazulu/Natal        Pinetown
# 48     Kwazulu/Natal         Phoenix
# 51     Kwazulu/Natal  Durban Central
# ...              ...             ...
# 30829  Kwazulu/Natal      Kwamashu E
# 30830  Kwazulu/Natal      Kwamashu E
# 30840  Kwazulu/Natal  Port Shepstone
# 30850  Kwazulu/Natal      Kwamashu E
# 30855  Kwazulu/Natal      Kwamashu E
#
#                                                 Category  2005-2006  \
# 6                      All theft not mentioned elsewhere       4162
# 17                Robbery with aggravating circumstances       2721
# 34                     All theft not mentioned elsewhere       2143
# 48                                    Drug-related crime       1950
# 51                 Theft of motor vehicle and motorcycle       1919
# ...                                                  ...        ...
# ...

# %%
common_crimeKZ = kwazulu.groupby(['Category']).sum()
common_crimeKZ
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                       53778      50046
# Arson                                                    1214       1226
# Assault with the intent to inflict grievous bod...      30993      30638
# Attempted murder                                         5255       5188
# Bank robbery                                                6         11
# Burglary at non-residential premises                     8982       9417
# Burglary at residential premises                        40631      39486
# Carjacking                                               3070       3544
# Commercial crime                                         7941      10366
# Common assault                                          33735      31488
# Common robbery                                          11688      10532
# Driving under the influence of alcohol or drugs          7843       9780
# ...

# %%
common_crimeKZ.plot(kind='bar', figsize = (15, 6), rot=90)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.title('Common crimes in Kwazulu')
# Out:
# Text(0.5, 1.0, 'Common crimes in Kwazulu')

# %%
mpumalanga = df[df["Province"]=="Mpumalanga"]
mpumalanga
# Out:
#          Province               Station  \
# 10     Mpumalanga             Nelspruit
# 24     Mpumalanga               Witbank
# 47     Mpumalanga  Middelburg Mpumalang
# 130    Mpumalanga                Vosman
# 133    Mpumalanga               Witbank
# ...           ...                   ...
# 30732  Mpumalanga               Pienaar
# 30744  Mpumalanga               Pienaar
# 30750  Mpumalanga               Pienaar
# 30810  Mpumalanga               Pienaar
# 30825  Mpumalanga               Pienaar
#
#                                                 Category  2005-2006  \
# 10                     All theft not mentioned elsewhere       3481
# 24                     All theft not mentioned elsewhere       2437
# 47                     All theft not mentioned elsewhere       1956
# 130                    All theft not mentioned elsewhere       1362
# 133                     Burglary at residential premises       1355
# ...

# %%
common_crimeMP = mpumalanga.groupby(['Category']).sum()
common_crimeMP
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                       28518      26361
# Arson                                                     601        640
# Assault with the intent to inflict grievous bod...      18636      17955
# Attempted murder                                         1334       1300
# Bank robbery                                                2          7
# Burglary at non-residential premises                     2926       3478
# Burglary at residential premises                        20305      19444
# Carjacking                                                515        594
# Commercial crime                                         2564       2789
# Common assault                                          14140      13472
# Common robbery                                           5167       5147
# Driving under the influence of alcohol or drugs          1129       1333
# ...

# %%
common_crimeMP.plot(kind='bar', figsize = (15, 6), rot=90)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.title('Common crimes in Mpumalanga')
# Out:
# Text(0.5, 1.0, 'Common crimes in Mpumalanga')

# %%
e_cape = df[df["Province"]=="Eastern Cape"]
e_cape
# Out:
#            Province      Station  \
# 16     Eastern Cape  East London
# 19     Eastern Cape     Humewood
# 32     Eastern Cape   Mount Road
# 106    Eastern Cape    Cambridge
# 108    Eastern Cape       Walmer
# ...             ...          ...
# 30786  Eastern Cape      Madeira
# 30791  Eastern Cape         Joza
# 30792  Eastern Cape      Madeira
# 30807  Eastern Cape      Madeira
# 30813  Eastern Cape      Madeira
#
#                                                 Category  2005-2006  \
# 16                     All theft not mentioned elsewhere       2892
# 19                     All theft not mentioned elsewhere       2585
# 32                     All theft not mentioned elsewhere       2234
# 106                    All theft not mentioned elsewhere       1478
# 108                     Burglary at residential premises       1467
# ...                                                  ...        ...
# 30786                                        Shoplifting          0
# ...

# %%
common_crimeEC = e_cape.groupby(['Category']).sum()
common_crimeEC
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                       40001      37298
# Arson                                                    1281       1243
# Assault with the intent to inflict grievous bod...      37196      35244
# Attempted murder                                         2508       2136
# Bank robbery                                                2          5
# Burglary at non-residential premises                     6015       5366
# Burglary at residential premises                        32978      31421
# Carjacking                                                518        600
# Commercial crime                                         4320       5453
# Common assault                                          22509      20840
# Common robbery                                           8135       7642
# Driving under the influence of alcohol or drugs          3839       4723
# ...

# %%
common_crimeEC.plot(kind='bar', figsize = (15, 6), rot=90)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.title('Common crimes in Eastern Cape')
# Out:
# Text(0.5, 1.0, 'Common crimes in Eastern Cape')

# %%
limpopo = df[df["Province"]=="Limpopo"]
limpopo
# Out:
#       Province      Station  \
# 23     Limpopo    Polokwane
# 65     Limpopo  Thohoyandou
# 119    Limpopo    Polokwane
# 170    Limpopo      Tzaneen
# 178    Limpopo  Thohoyandou
# ...        ...          ...
# 30833  Limpopo  Mokwakwaila
# 30839  Limpopo  Mokwakwaila
# 30845  Limpopo  Mokwakwaila
# 30846  Limpopo   Westenburg
# 30851  Limpopo   Westenburg
#
#                                                 Category  2005-2006  \
# 23                     All theft not mentioned elsewhere       2499
# 65                                        Common assault       1787
# 119                   Theft out of or from motor vehicle       1402
# 170                    All theft not mentioned elsewhere       1225
# 178    Assault with the intent to inflict grievous bo...       1175
# ...                                                  ...        ...
# 30833                  All theft not mentioned elsewhere          0
# 30839         Sexual offences as result of police action          0
# ...

# %%
common_crimeLP = limpopo.groupby(['Category']).sum()
common_crimeLP
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                       20237      19769
# Arson                                                     652        653
# Assault with the intent to inflict grievous bod...      15845      15635
# Attempted murder                                          812        814
# Bank robbery                                                1          6
# Burglary at non-residential premises                     4758       4743
# Burglary at residential premises                        12768      12346
# Carjacking                                                164        189
# Commercial crime                                         1888       2248
# Common assault                                          14558      13054
# Common robbery                                           4565       4434
# Driving under the influence of alcohol or drugs           831       1116
# ...

# %%
common_crimeLP.plot(kind='bar', figsize = (15, 6), rot=90)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.title('crime rates in Limpopo')
# Out:
# Text(0.5, 1.0, 'crime rates in Limpopo')

# %%
northern_cape = df[df["Province"]=="Northern Cape"]
northern_cape
# Out:
#             Province    Station  \
# 46     Northern Cape  Kimberley
# 74     Northern Cape  Galeshewe
# 189    Northern Cape  Kimberley
# 250    Northern Cape  Galeshewe
# 283    Northern Cape  Kimberley
# ...              ...        ...
# 30665  Northern Cape    Kagisho
# 30677  Northern Cape    Kagisho
# 30703  Northern Cape    Kagisho
# 30728  Northern Cape    Kagisho
# 30811  Northern Cape    Kagisho
#
#                                                 Category  2005-2006  \
# 46                     All theft not mentioned elsewhere       1970
# 74     Assault with the intent to inflict grievous bo...       1683
# 189                   Theft out of or from motor vehicle       1144
# 250                                       Common assault        999
# 283                                       Common assault        939
# ...                                                  ...        ...
# 30665                       Malicious damage to property          0
# ...

# %%
common_crimeNC = northern_cape.groupby(['Category']).sum()
common_crimeNC
# Out:
#                                                     2005-2006  2006-2007  \
# Category
# All theft not mentioned elsewhere                        8885       7809
# Arson                                                     194        196
# Assault with the intent to inflict grievous bod...      11478      10857
# Attempted murder                                         1053       1008
# Bank robbery                                                0          1
# Burglary at non-residential premises                     1990       2067
# Burglary at residential premises                         6078       5488
# Carjacking                                                  4          4
# Commercial crime                                          708        818
# Common assault                                           6813       6288
# Common robbery                                           1894       1518
# Driving under the influence of alcohol or drugs           958       1014
# ...

# %%
common_crimeNC.plot(kind='bar', figsize = (15, 6), rot=90)
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.title('crime rates in Northern cape')
# Out:
# Text(0.5, 1.0, 'crime rates in Northern cape')
